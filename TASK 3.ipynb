# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Auto Sales data.csv")

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# 0     Land of Toys Inc.        2125557818        897 Long Airport Avenue
# 1    Reims Collectables        26.47.1555             59 rue de l'Abbaye
# 2       Lyon Souveniers  +33 1 46 62 7555  27 rue du Colonel Pierre Avia
# 3     Toys4GrownUps.com        6265557265             78934 Hillside Dr.
# 4  Technics Stores Inc.        6505556809              9408 Furth Circle
#
#          CITY POSTALCODE COUNTRY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         NYC      10022     USA              Yu             Kwai    Small
# 1       Reims      51100  France         Henriot             Paul    Small
# 2       Paris      75508  France        Da Cunha           Daniel   Medium
# 3    Pasadena      90003     USA           Young            Julie   Medium
# 4  Burlingame      94217     USA          Hirano             Juri   Medium

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS PRODUCTLINE  MSRP  \
# 2742  02/12/2019                  2924   Shipped       Ships    54
# 2743  31/01/2020                  2865   Shipped       Ships    54
# 2744  01/03/2020                  2836  Resolved       Ships    54
# 2745  28/03/2020                  2810   Shipped       Ships    54
# 2746  06/05/2020                  2772   On Hold       Ships    54
#
#      PRODUCTCODE             CUSTOMERNAME           PHONE  \
# 2742    S72_3212    Euro Shopping Channel  (91) 555 94 44
# 2743    S72_3212  Oulu Toy Supplies, Inc.      981-443655
# 2744    S72_3212    Euro Shopping Channel  (91) 555 94 44
# 2745    S72_3212             Alpha Cognac      61.77.6555
# 2746    S72_3212        Gifts4AllAges.com      6175559555
#
#                ADDRESSLINE1      CITY POSTALCODE  COUNTRY CONTACTLASTNAME  \
# 2742     C/ Moralzarzal, 86    Madrid      28034    Spain          Freyre
# 2743            Torikatu 38      Oulu      90110  Finland       Koskitalo
# 2744     C/ Moralzarzal, 86    Madrid      28034    Spain          Freyre
# 2745  1 rue Alsace-Lorraine  Toulouse      31000   France          Roulet
# 2746     8616 Spinnaker Dr.    Boston      51003      USA         Yoshido
#
#      CONTACTFIRSTNAME DEALSIZE
# 2742            Diego    Small
# 2743           Pirkko   Medium
# 2744            Diego   Medium
# 2745          Annette    Small
# 2746             Juri   Medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   object
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
#  15  POSTALCODE            2747 non-null   object
#  16  COUNTRY               2747 non-null   object
#  17  CONTACTLASTNAME       2747 non-null   object
#  18  CONTACTFIRSTNAME      2747 non-null   object
#  19  DEALSIZE              2747 non-null   object
# dtypes: float64(2), int64(5), object(13)
# memory usage: 429.3+ KB

# %%
df.shape
# Out:
# (2747, 20)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'DAYS_SINCE_LASTORDER', 'STATUS', 'PRODUCTLINE',
#        'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'CITY',
#        'POSTALCODE', 'COUNTRY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# PHONE                   0
# ADDRESSLINE1            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# CONTACTLASTNAME         0
# CONTACTFIRSTNAME        0
# DEALSIZE                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'], dayfirst=True)

# %%
df['YEAR'] = df['ORDERDATE'].dt.year
df['MONTH'] = df['ORDERDATE'].dt.month
df['DAY'] = df['ORDERDATE'].dt.day

# %%
df.dtypes
# Out:
# ORDERNUMBER                      int64
# QUANTITYORDERED                  int64
# PRICEEACH                      float64
# ORDERLINENUMBER                  int64
# SALES                          float64
# ORDERDATE               datetime64[ns]
# DAYS_SINCE_LASTORDER             int64
# STATUS                          object
# PRODUCTLINE                     object
# MSRP                             int64
# PRODUCTCODE                     object
# CUSTOMERNAME                    object
# PHONE                           object
# ADDRESSLINE1                    object
# CITY                            object
# POSTALCODE                      object
# COUNTRY                         object
# CONTACTLASTNAME                 object
# CONTACTFIRSTNAME                object
# DEALSIZE                        object
# YEAR                             int32
# MONTH                            int32
# DAY                              int32
# dtype: object

# %%
df.drop([
    'PHONE',
    'ADDRESSLINE1',
    'CONTACTFIRSTNAME',
    'CONTACTLASTNAME'
], axis=1, inplace=True)

# %%
df['COUNTRY'].unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %%
df['STATUS'].unique()
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
df['DEALSIZE'].unique()
# Out:
# array(['Small', 'Medium', 'Large'], dtype=object)

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
# std       91.877521         9.762135    42.042549         4.230544
#
#               SALES                      ORDERDATE  DAYS_SINCE_LASTORDER  \
# count   2747.000000                           2747           2747.000000
# mean    3553.047583  2019-05-13 21:56:17.211503360           1757.085912
# min      482.130000            2018-01-06 00:00:00             42.000000
# 25%     2204.350000            2018-11-08 00:00:00           1077.000000
# 50%     3184.800000            2019-06-24 00:00:00           1761.000000
# 75%     4503.095000            2019-11-17 00:00:00           2436.500000
# max    14082.800000            2020-05-31 00:00:00           3562.000000
# std     1838.953901                            NaN            819.280576
#
#               MSRP         YEAR        MONTH          DAY
# count  2747.000000  2747.000000  2747.000000  2747.000000
# mean    100.691664  2018.822352     7.083364    14.306880
# min      33.000000  2018.000000     1.000000     1.000000
# 25%      68.000000  2018.000000     4.000000     6.000000
# 50%      99.000000  2019.000000     8.000000    14.000000
# 75%     124.000000  2019.000000    11.000000    21.000000
# max     214.000000  2020.000000    12.000000    31.000000
# std      40.114802     0.696288     3.641826     8.833086

# %%
import matplotlib.pyplot as plt

df.boxplot(column='SALES')
plt.show()

# %%
df.boxplot(column='PRICEEACH')
plt.show()

# %%
df['COUNTRY'] = df['COUNTRY'].str.strip()
df['STATUS'] = df['STATUS'].str.strip()

# %%
df['Sales_Category'] = pd.cut(
    df['SALES'],
    bins=[0, 1000, 3000, 5000, 10000],
    labels=['Low', 'Medium', 'High', 'Very High']
)

# %%
df.sort_values(by='ORDERDATE', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2747 entries, 1959 to 1022
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  CITY                  2747 non-null   object
#  13  POSTALCODE            2747 non-null   object
#  14  COUNTRY               2747 non-null   object
#  15  DEALSIZE              2747 non-null   object
#  16  YEAR                  2747 non-null   int32
#  17  MONTH                 2747 non-null   int32
#  18  DAY                   2747 non-null   int32
#  19  Sales_Category        2732 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(2), int32(3), int64(5), object(8)
# memory usage: 399.9+ KB

# %%
df.head()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1959        10100               49      34.47                1  1689.03
# 652         10100               50      67.80                2  3390.00
# 1219        10100               22      86.51                4  1903.22
# 552         10100               30     171.70                3  5151.00
# 797         10101               26     145.13                1  3773.38
#
#       ORDERDATE  DAYS_SINCE_LASTORDER   STATUS   PRODUCTLINE  MSRP  \
# 1959 2018-01-06                  2836  Shipped  Vintage Cars    41
# 652  2018-01-06                  1529  Shipped  Vintage Cars    60
# 1219 2018-01-06                  2096  Shipped  Vintage Cars    92
# 552  2018-01-06                  1429  Shipped  Vintage Cars   170
# 797  2018-01-09                  1671  Shipped  Vintage Cars   168
#
#      PRODUCTCODE                  CUSTOMERNAME       CITY POSTALCODE  COUNTRY  \
# 1959    S24_3969  Online Diecast Creations Co.     Nashua      62005      USA
# 652     S18_2248  Online Diecast Creations Co.     Nashua      62005      USA
# 1219    S18_4409  Online Diecast Creations Co.     Nashua      62005      USA
# 552     S18_1749  Online Diecast Creations Co.     Nashua      62005      USA
# 797     S18_2795          Blauer See Auto, Co.  Frankfurt      60528  Germany
#
#      DEALSIZE  YEAR  MONTH  DAY Sales_Category
# 1959    Small  2018      1    6         Medium
# 652    Medium  2018      1    6           High
# 1219    Small  2018      1    6         Medium
# 552    Medium  2018      1    6      Very High
# 797    Medium  2018      1    9           High

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER              0
# QUANTITYORDERED          0
# PRICEEACH                0
# ORDERLINENUMBER          0
# SALES                    0
# ORDERDATE                0
# DAYS_SINCE_LASTORDER     0
# STATUS                   0
# PRODUCTLINE              0
# MSRP                     0
# PRODUCTCODE              0
# CUSTOMERNAME             0
# CITY                     0
# POSTALCODE               0
# COUNTRY                  0
# DEALSIZE                 0
# YEAR                     0
# MONTH                    0
# DAY                      0
# Sales_Category          15
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# DEALSIZE                0
# YEAR                    0
# MONTH                   0
# DAY                     0
# Sales_Category          0
# dtype: int64

# %%
df.to_csv("Cleaned_Auto_Sales.csv", index=False)

# %%
df.shape
# Out:
# (2732, 20)
